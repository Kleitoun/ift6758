# %% [markdown]
# # 4. Tidy Data
#
# Refer to ift6758/data/question_2_4.py for functions used to import the data.
#
# This takes a while to run, so run it only once, save output as csv and import the csv for future uses

# %%
import sys
sys.path.append('../ift6758/data')

from data.question_2_4 import *

# %%
import json

# %%
df = tidy_df_loop()
# Out:
# finished 2016 season
# finished 2017 season
# finished 2018 season
# finished 2019 season
# finished 2020 season

# %%
df.to_csv('tidy_df.csv')

# %% [markdown]
# ## 4.1
#
# In your blog post, include a small snippet of your final dataframe (e.g. using head(10)). You can just include a screenshot rather than fighting to get the tables neatly formatted in HTML/markdown.

# %%
import json
import pandas as pd
df = pd.read_csv('tidy_df.csv')

# %%
df.sample(10)
# Out:
#         Unnamed: 0     game_id    season season_type              home_team  \
# 303342       49867  2019020788  20192020           R    Carolina Hurricanes
# 224837       57301  2018020908  20182019           R       Florida Panthers
# 350141       20625  2020020340  20202021           R         Buffalo Sabres
# 213699       46163  2018020734  20182019           R  Columbus Blue Jackets
# 87997         7598  2017020117  20172018           R  Columbus Blue Jackets
# 343185       13669  2020020225  20202021           R     Colorado Avalanche
# 64617        64617  2016021059  20162017           R         Minnesota Wild
# 125478       45079  2017020702  20172018           R    Nashville Predators
# 203218       35682  2018020565  20182019           R   Vegas Golden Knights
# 144822       64423  2017020999  20172018           R          Anaheim Ducks
#
#                     away_team home_team_side_1st_period  \
# 303342   Vegas Golden Knights                     right
# 224837     Montréal Canadiens                     right
# 350141    Philadelphia Flyers                      left
# 213699     Montréal Canadiens                      left
# 87997       Los Angeles Kings                      left
# 343185        Arizona Coyotes                     right
# 64617        New York Rangers                     right
# 125478        Arizona Coyotes                      left
# 203218      Los Angeles Kings                       NaN
# 144822  Columbus Blue Jackets                      left
#
#                attacking_team    attacking_player             goalie  ...  \
# 303342   Vegas Golden Knights         Nicolas Roy        Petr Mrazek  ...
# 224837     Montréal Canadiens            Max Domi       James Reimer  ...
# 350141    Philadelphia Flyers      Oskar Lindblom    Jonas Johansson  ...
# 213699  Columbus Blue Jackets  Oliver Bjorkstrand        Carey Price  ...
# 87997   Columbus Blue Jackets        Nick Foligno     Jonathan Quick  ...
# 343185     Colorado Avalanche         Devon Toews     Ivan Prosvetov  ...
# 64617        New York Rangers           Rick Nash       Devan Dubnyk  ...
# 125478    Nashville Predators     Miikka Salomaki       Antti Raanta  ...
# 203218      Los Angeles Kings        Adrian Kempe  Marc-Andre Fleury  ...
# 144822  Columbus Blue Jackets      Artemi Panarin        John Gibson  ...
#
#         goal_ind shot_ind  x_coordinates  y_coordinates   shot_type  \
# 303342         0        1           85.0           19.0  Wrist Shot
# 224837         1        0           76.0            0.0  Wrist Shot
# 350141         0        1           67.0            7.0  Wrist Shot
# 213699         0        1           84.0           -6.0  Wrist Shot
# 87997          0        1           83.0           -4.0    Backhand
# 343185         0        1          -21.0           19.0  Wrist Shot
# 64617          0        1           87.0           29.0  Wrist Shot
# 125478         0        1           76.0           16.0  Wrist Shot
# 203218         0        1           52.0           29.0  Wrist Shot
# 144822         0        1          -52.0           -1.0  Wrist Shot
#
#         empty_net strength    gwg distance_from_net attacking_team_side
# 303342        NaN      NaN    NaN         19.416488                left
# 224837      False     Even  False         13.000000                left
# 350141        NaN      NaN    NaN         23.086793                left
# 213699        NaN      NaN    NaN          7.810250                left
# 87997         NaN      NaN    NaN          7.211103                left
# 343185        NaN      NaN    NaN         70.604532               right
# 64617         NaN      NaN    NaN         29.068884                left
# 125478        NaN      NaN    NaN         20.615528                left
# 203218        NaN      NaN    NaN         47.010637                left
# 144822        NaN      NaN    NaN         37.013511               right
#
# [10 rows x 22 columns]

# %% [markdown]
# ## 4.2
# You’ll notice that the “strength” field (i.e. even, power play, short handed) only exists for goals, not shots. Furthermore, it doesn’t include the actual strength of players on the ice (i.e. 5 on 4, or 5 on 3, etc). Discuss how you could add the actual strength information (i.e. 5 on 4, etc.) to both shots and goals, given the other event types (beyond just shots and goals) and features available. You don’t need to implement this for this milestone.
#
# A: By looking at the 'Penalty' and 'Goal' events we can logically deduce the strength at any given time in the game (by looking at penalty times, goals, etc). For example, a minor penalty usually lasts 2 minutes, unless the opposing team scores a goal, in which case it ends early. We can use this logic (along with some manipulations related to period number and time) to build a table which contains the strength at every second of each game. Then, when we have the events data, we can get the strengh for each event by joining that table. See cell below for sample penalty event

# %%
data_folder_path = './'
f = open(data_folder_path + '2016020001.json')
sample_game = json.load(f)
sample_game['liveData']['plays']['allPlays'][74]
# Out:
# {'players': [{'player': {'id': 8474697,
#     'fullName': 'Mark Borowiecki',
#     'link': '/api/v1/people/8474697'},
#    'playerType': 'PenaltyOn'},
#   {'player': {'id': 8474709,
#     'fullName': 'Matt Martin',
#     'link': '/api/v1/people/8474709'},
#    'playerType': 'DrewBy'}],
#  'result': {'event': 'Penalty',
#   'eventCode': 'OTT47',
#   'eventTypeId': 'PENALTY',
#   'description': 'Mark Borowiecki Fighting against Matt Martin',
#   'secondaryType': 'Fighting',
#   'penaltySeverity': 'Major',
#   'penaltyMinutes': 5},
#  'about': {'eventIdx': 74,
#   'eventId': 47,
#   'period': 1,
#   'periodType': 'REGULAR',
#   'ordinalNum': '1st',
#   'periodTime': '13:25',
#   'periodTimeRemaining': '06:35',
#   'dateTime': '2016-10-12T23:42:40Z',
#   'goals': {'away': 1, 'home': 2}},
#  'coordinates': {'x': -90.0, 'y': -12.0},
#  'team': {'id': 9,
#   'name': 'Ottawa Senators',
#   'link': '/api/v1/teams/9',
#   'triCode': 'OTT'}}

# %% [markdown]
# ## 4.3
# In a few sentences, discuss some additional features you could consider creating from the data available in this dataset. We’re not looking for any particular answers, but if you need some inspiration, could a shot or goal be classified as a rebound, or a shot off the rush?
#
# A:
#
#  - Based on coordinates, you could classify shots as low/high danger or as coming from a particular zone
#  - Shot/goal can be probably be classified as a rebound if there was another shot from the same team < x seconds prior (not 100% accurate though)
#  - We are not sure if there is enough info to reliably method to classify a shot/goal as being off the rush
#  - Anything that can be created from the set of events below: {'Blocked Shot', 'Faceoff', 'Game End', 'Game Official', 'Game Scheduled', 'Giveaway', 'Goal', 'Hit', 'Missed Shot', 'Penalty', 'Period End', 'Period Official', 'Period Ready', 'Period Start', 'Shot', 'Stoppage', 'Takeaway'}
